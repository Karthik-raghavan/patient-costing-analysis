# %%
import pandas as pd
import datetime

# %%
patient_data = pd.read_csv('dataset/dashboard_data.csv')

# %%
patient_data
# Out:
#            DateKey  AdmissionMethod  Age Consultant  Consultant Comments  \
# 0       2019-07-30               21   83   C3289011                26657
# 1       2019-07-30               22   34   C3499117                78221
# 2       2019-07-30               22   34   C3499117                78222
# 3       2019-07-30               22   34   C3499117                78223
# 4       2019-07-30               22   34   C3499117                78224
# ...            ...              ...  ...        ...                  ...
# 211228  2019-07-30               21   83   C3289011                26652
# 211229  2019-07-30               21   83   C3289011                26653
# 211230  2019-07-30               21   83   C3289011                26654
# 211231  2019-07-30               21   83   C3289011                26655
# 211232  2019-07-30               21   83   C3289011                26656
#
#              Cost  cResElem cResElem2Name cResElem3 cResElemName  ...  \
# ...

# %%
print(list(patient_data.columns))
# Out:
# ['DateKey', 'AdmissionMethod', 'Age', 'Consultant', 'Consultant Comments', 'Cost', 'cResElem', 'cResElem2Name', 'cResElem3', 'cResElemName', 'cResElem3Name', 'cResItem', 'DischargeMethod', 'DominantDiagnosis', 'DominantProcedure_Code', 'AdmissionDate', 'DischargeDate', 'EpisodeID', 'HRG', 'IncomeChildTopup', 'IncomeExcessBedDays', 'IncomeTariff', 'IncomeTopUp', 'PatientID', 'PatientType', 'PercentageSplit', 'resItemName', 'GenderId', 'Specialty', 'Units(days)', 'Country', 'State', 'City', 'Admission Type', 'Admission Desc Group', 'Admission Description', 'Discharge Description', 'Discharge Type', 'Gender', 'HRG Label', 'DayAbbr', 'MonthDayNum', 'YearNum', 'YearMonth', 'MonthAbbr', 'MonthNum', 'DayDate', 'MonthStartDate', 'MonthEndDate', 'PrevYearNum', 'PrevMonthNum', 'cResElementName', 'SpecialtyDescription', 'Surgical Specialties', 'Comments', 'Description']

# %%
# Patient Count

# %%
patient_data['PatientID'].nunique()
# Out:
# 10720

# %%
# Averages for length of stay (LOS),

# %%
#patient_data['DischargeDate'] - patient_data['AdmissionDate']

# %%
# Revenue

# %%
# max IncomeChildTopup + IncomeExcessBedDays + IncomeTariff - sum IncomeTopUp
# aggregated by patient id and admission date

# %%
# Profitability

# %%
# Revenue - Cost
# Line Chart
